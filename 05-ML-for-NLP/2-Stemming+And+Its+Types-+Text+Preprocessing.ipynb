# %% [markdown]
# ## Stemming
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
## Classification Problem
## Comments of product is a positive review or negative review
## Reviews----> eating, eat,eaten [going,gone,goes]--->go

words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# # 🔪 Stemming - Reducing Words to Root Form
#
# **Goal**: Reduce words to their base/root form to decrease vocabulary size
#
# ## Why Stemming?
# - Reduces feature space (eating, eats, eaten → eat)
# - Improves model efficiency
# - Useful for classification tasks
#
# ## Trade-off:
# ✅ **Fast** - Rule-based, no dictionary lookup
# ❌ **Inaccurate** - May produce non-words (history → histori)
#
# **When to use**: Spam detection, sentiment analysis, search engines

# %%
from nltk.stem import PorterStemmer

# %% [markdown]
# ## 1️⃣ Porter Stemmer
#
# **Most common stemmer** - Oldest and widely used
#
# **How it works**: Applies a series of rules to remove suffixes
#
# **Problem**: Can produce non-English words
# - congratulations → congratul ❌
# - history → histori ❌

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ## 2️⃣ Regex Stemmer
#
# **Custom rule-based stemming** using regular expressions
#
# **Use case**: When you need domain-specific stemming control
#
# **How it works**: You define patterns to remove (ing$, s$, able$)
#
# **Advantage**: Full control over what gets removed

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ## 3️⃣ Snowball Stemmer (Recommended! ✅)
#
# **Improved version of Porter Stemmer**
#
# **Why better**:
# - More accurate than Porter
# - Supports multiple languages
# - Better word forms (fairly → fair instead of fairli)
#
# **Recommendation**: Use this instead of Porter for better results!

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer('english')

# %%
for word in words:
    print(word+"---->"+snowballsstemmer.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalized---->final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballsstemmer.stem('goes')
# Out:
# 'goe'

# %%
stemming.stem('goes')
# Out:
# 'goe'

# %% [markdown]
# ---
#
# ## ✅ Checkpoint: What You Learned
#
# - ✅ What stemming is and why it's needed
# - ✅ Porter Stemmer (most common, but inaccurate)
# - ✅ Regex Stemmer (custom rules)
# - ✅ Snowball Stemmer (best choice!) ⭐
# - ✅ Trade-off: Speed vs Accuracy
#
# ---
#
# ## 🎯 Next Step
#
# Stemming is fast but produces non-words. Want better accuracy?
#
# **Next Notebook**: `3-Lemmatization-+Text+Preprocessing.ipynb`
#
# **What you'll learn**: Dictionary-based root finding with perfect English words!
#
# ---
#
# 💡 **Key Takeaway**: Use Snowball for stemming, but lemmatization is better for accuracy!
